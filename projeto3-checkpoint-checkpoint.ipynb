# %% [markdown]
# Gabriel Camargo
# Pedro Fonseca
# Victor Aprigliano
#
# Tema: Regressão - Preço das Casas em King Country, USA.

# %%
# %matplotlib inline
import math
from sys import stdin
import pandas as pd
import matplotlib.pyplot as plt
import os
from numpy import arange
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
dados = pd.read_csv('kc_house_data.csv',sep=',')
for j in dados.columns:
    if j!='date':
        if j!='id':
            if j!='price':
                print(j)
                print(dados[j].corr(dados['price'])) #mais 3 pq as as duas primeiras nao sao quantitativas e a terceira eh o proprio preco
# Out:
# bedrooms
# 0.308349598146
# bathrooms
# 0.525137505414
# sqft_living
# 0.702035054612
# sqft_lot
# 0.0896608605871
# floors
# 0.256793887551
# waterfront
# 0.266369434031
# view
# 0.397293488295
# condition
# 0.036361789129
# grade
# 0.66743425602
# sqft_above
# 0.605567298356
# sqft_basement
# 0.323816020712
# yr_built
# 0.0540115314948
# yr_renovated
# 0.126433793441
# zipcode
# -0.0532028542983
# lat
# 0.307003479995
# long
# 0.0216262410393
# sqft_living15
# 0.58537890358
# sqft_lot15
# 0.0824471525195

# %% [markdown]
# Para a regressao escolhemos as variaveis com correlacao mais forte com o preco:

# %%
dados = dados.loc[:,['date','price','bedrooms',"bathrooms",'sqft_living','sqft_above',"grade"]]
#dados.columns=["Data de compra","Preço (US DOLLAR)","Nº Quartos","Nº Banheiros",'Área de Lazer',"Área Térrea","Avaliação"]
#dados['Data'] = pd.to_datetime(dados.Data).dados.strftime('%d/%m/%Y')
dados.head()
# Out:
#               date     price  bedrooms  bathrooms  sqft_living  sqft_above  \
# 0  20141013T000000  221900.0         3       1.00         1180        1180
# 1  20141209T000000  538000.0         3       2.25         2570        2170
# 2  20150225T000000  180000.0         2       1.00          770         770
# 3  20141209T000000  604000.0         4       3.00         1960        1050
# 4  20150218T000000  510000.0         3       2.00         1680        1680
#
#    grade
# 0      7
# 1      7
# 2      6
# 3      7
# 4      8

# %%
fig = plt.figure(figsize=(11, 5))
#faixa = arange(1000,2000000,30000)
dados["lnprice"]=(np.log((dados.price)))/(np.log(math.e))
plot= dados.lnprice.plot.hist( title='Histograma Preco', normed=1, alpha=0.6,color = 'b')
plt.ylabel('Densidade')
plt.xlabel("Preco [Dolares americanos]")
plt.show()

# %%
pm=dados.price.mean()
gm=dados.grade.mean()
Sxx=0
Sxy=0
for a in range(len(dados)):
    Sxy=Sxy+((dados.grade[a])-gm)*(dados.price[a]-pm)
    Sxx=Sxx+(((dados.grade[a])-gm)**2)
b1=Sxy/Sxx
print("b1:")
print(b1)
b0=pm-gm*b1
print("b0:")
print(b0)
e1=[]
SSe=0
SSr=0
for a in range(len(dados)):
    e1.append(dados.price[a]-(b0+b1*(dados.grade[a])))
    SSe=SSe+(dados.price[a]-(b0+b1*(dados.grade[a])))**2
    SSr=SSr+(dados.price[a]-pm)**2
SSt=SSr+SSe
Rsqt=1-(SSe/SSt)
print(Rsqt)
#X=dados[['bathrooms','grade','sqft_living','sqft_above']]
# Out:
# b1:
# 208457.562458
# b0:
# -1056044.97701
# 0.643280622531

# %%
import statsmodels.api as sm
Y = dados['lnprice']
minhascolunas=['grade','sqft_living','sqft_above']
X=dados[['grade','sqft_living','sqft_above']]
X=sm.add_constant(X)
model = sm.OLS(Y,X)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                lnprice   R-squared:                       0.564
# Model:                            OLS   Adj. R-squared:                  0.564
# Method:                 Least Squares   F-statistic:                     9330.
# Date:                Mon, 13 Nov 2017   Prob (F-statistic):               0.00
# Time:                        15:07:01   Log-Likelihood:                -7830.8
# No. Observations:               21613   AIC:                         1.567e+04
# Df Residuals:                   21609   BIC:                         1.570e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const          11.0845      0.019    585.450      0.000      11.047      11.122
# grade           0.2049      0.003     63.219      0.000       0.199       0.211
# sqft_living     0.0003   5.64e-06     53.558      0.000       0.000       0.000
# sqft_above     -0.0001   6.18e-06    -21.175      0.000      -0.000      -0.000
# ==============================================================================
# Omnibus:                       36.718   Durbin-Watson:                   1.974
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               36.850
# Skew:                           0.100   Prob(JB):                     9.96e-09
# Kurtosis:                       3.026   Cond. No.                     2.43e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.43e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
PE=[]
PR=[]
b=0
c=0
for a in range(len(dados)):
    if math.e**(11.0845+(0.0003*(dados.sqft_living[a]))-(0.0001*(dados.sqft_above[a]))+(0.2049*(dados.grade[a])))<10**7:
        PE.append(math.e**(11.0845+(0.0003*(dados.sqft_living[a]))-(0.0001*(dados.sqft_above[a]))+(0.2049*(dados.grade[a]))))
        PR.append(dados.price[a])
import seaborn as sns
# %matplotlib inline
sns.pairplot(dados,x_vars=minhascolunas,y_vars="price",size=7,aspect=0.7,kind = 'reg')

# %%
scatter_plot = plt.scatter(PE,PR)
plt.plot()
plt.show()
